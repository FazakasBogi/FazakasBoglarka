# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
hu = pd.read_csv("../data/raw/Hungary.csv")
ro = pd.read_csv("../data/raw/Romania.csv")
nl_forms = pd.read_csv("../data/raw/Netherlands_forms.csv")
nl_swap = pd.read_csv("../data/raw/Netherlands_surveyswap.csv")

# %%
nl_swap.columns.tolist()
# Out:
# ['Submitted at',
#  'Respondent',
#  'Are you from the Netherlands, or have you been living there for a minimum of 1 year?',
#  '1. I am concerned when the environment is damaged, even if it does not directly affect me. (1 = does not apply to me at all, 6 = applies to me completely)',
#  '2. I believe it is important that my decisions do not harm those around me or future generations.\n(1 = does not apply to me at all, 6 = applies to me completely)',
#  '3. I strive to follow rules and standards that serve the good of the community or society as a whole.\n(1 = does not apply to me at all, 6 = applies to me completely)',
#  '4. I believe it is important for society to continue to function within a sustainable and stable framework in the future. \n(1 = does not apply to me at all, 6 = applies to me completely)',
#  '5. What can you do with a broken, unused smartphone? Select all the options you think are correct!',
#  '6. Have you ever heard of the term "e-waste" or WEEE?',
# ...
